# %%
import pandas as pd
#read data from .csv
csvdf=pd.read_csv("data.csv")
csvdf

# %%
jsondf=pd.read_json('data1.json')
jsondf

# %%
exceldf=pd.read_excel('indian_users.xlsx')
exceldf

# %%
csvdf.to_csv("output.csv",index=False)

# %%
jsondf.to_json('jsonoutput.json',indent=False)

# %%
exceldf.to_excel('exceloutput.xlsx',index=False)

# %%
titaniccsv=pd.read_csv('titanic.csv')
titaniccsv
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titaniccsv.shape
# Out:
# (891, 12)

# %%
titaniccsv.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# print(titaniccsv[["PassengerId","Pclass","Age"]])

# %%
print(titaniccsv[titaniccsv['Sex']=='female'])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(titaniccsv[(titaniccsv['Fare'] >=70) & (titaniccsv['Sex'] == 'male')])
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 34            35         0       1
# 62            63         0       1
# 72            73         0       2
# 102          103         0       1
# 118          119         0       1
# 120          121         0       2
# 124          125         0       1
# 139          140         0       1
# 224          225         1       1
# 245          246         0       1
# 262          263         0       1
# 305          306         1       1
# 332          333         0       1
# 373          374         0       1
# 377          378         0       1
# 385          386         0       2
# 390          391         1       1
# 438          439         0       1
# 445          446         1       1
# 453          454         1       1
# 484          485         1       1
# 505          506         0       1
# 527          528         0       1
# 544          545         0       1
# ...

# %%
print(titaniccsv[titaniccsv['']=='female'])
